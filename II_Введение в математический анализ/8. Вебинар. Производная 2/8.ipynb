# %%
import numpy as np
import matplotlib.pyplot as plt

# Задаем рандомное распределение точек
x = np.random.uniform(-8, 8, 200)
a = np.random.uniform(0.5, 1.5, 200)
b = np.random.uniform(-1, 1, 200)

f = 1/(1+np.exp(-a*x-b))
plt.plot(x,f, marker="o", ls="")


plt.show()

# %%
###### import numpy as np
from scipy.optimize import fsolve, broyden1
import math

def equations(p):
    x, y = p
    # Запись системы уравнения вида x+y=2, x-y=0
    return (x+y-2, x-y)

# Численное решение нелинечной системы уравнений
x1, y1 =  fsolve(equations, (15, 15))
print (x1, y1)
# Out:
# 1.0 1.0

# %%
x1_ = np.sort(x)
f1_ = 1/(1+np.exp(-x1*x1_+y1))
plt.plot(x,f, marker="o", ls="")
plt.plot(x1_,f1_)

plt.show()

# %%
def equations(p):
    A, B = p
#     A = (-2*x*np.exp(-A*x-B)*(f-1/(1+np.exp(-A*x-B)))/(1+np.exp(-A*x-B))**2).sum()
#     B = (-2*np.exp(-A*x-B)*(f-1/(1+np.exp(-A*x-B)))/(1+np.exp(-A*x-B))**2).sum()
#     return (A, B)
    return ((-2*x*np.exp(-A*x-B)*(f-1/(1+np.exp(-A*x-B)))/(1+np.exp(-A*x-B))**2).sum(), (-2*np.exp(-A*x-B)*(f-1/(1+np.exp(-A*x-B)))/(1+np.exp(-A*x-B))**2).sum())

a, b =  fsolve(equations, (1, 1))
print (a, b)
# Out:
# 0.8825751853142313 0.10353799572655062

# %%
# a = 0.9
# b = -0.09

x_ = np.sort(x)
f_ = 1/(1+np.exp(-a*x_+b))
plt.plot(x,f, marker="o", ls="")
plt.plot(x_,f_)

plt.show()
