# %%
import numpy as np
import matplotlib.pyplot as plt

# Задаем рандомное распределение точек
x = np.random.uniform(-8, 8, 200)
a = np.random.uniform(0.5, 1.5, 200)
b = np.random.uniform(-1, 1, 200)

f = 1/(1+np.exp(-a*x-b))
plt.plot(x,f, marker="o", ls="")


plt.show()

# %%
###### import numpy as np
from scipy.optimize import fsolve, broyden1
import math

def equations(p):
    x, y = p
    # Запись системы уравнения вида x+y=2, x-y=0
    return (x+y-2, x-y)

# Численное решение нелинечной системы уравнений
x1, y1 =  fsolve(equations, (15, 15))
print (x1, y1)
# Out:
# 1.0 1.0

# %%
x1_ = np.sort(x)
f1_ = 1/(1+np.exp(-x1*x_+y1))
plt.plot(x,f, marker="o", ls="")
plt.plot(x1_,f1_)

plt.show()

# %%
def equations(p):
    a, b = p
    A = 0
    B = 0
    for i in range(len(f)):
        X = x[i]
        y = f[i]
        A = A - 2 * X**2 * math.e**(-a*X+b) / (( 1 + math.e**(-a*X+b)) ** 2)
        B = B + 2 * math.e**(-a*X+b) / (( 1 + math.e**(-a*X+b)) ** 2)
    return (A, B)

a, b =  fsolve(equations, (1, 1))
print (a, b)
# Out:
# 36.751381942782444 85.56874542889716
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in double_scalars
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in double_scalars
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':

# %%
# a = 0.9
# b = -0.09

x_ = np.sort(x)
f_ = 1/(1+np.exp(-a*x_+b))
plt.plot(x,f, marker="o", ls="")
plt.plot(x_,f_)

plt.show()
